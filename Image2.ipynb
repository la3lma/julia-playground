# %%
import Pkg; Pkg.add("TestImages"); 
import Pkg; Pkg.add("QuartzImageIO")

using TestImages
img = testimage("mandrill")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
# 512×512 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.643,0.588,0.278)  …  RGB{N0f8}(0.702,0.737,0.463)
#  RGB{N0f8}(0.471,0.49,0.243)      RGB{N0f8}(0.471,0.541,0.29)
#  RGB{N0f8}(0.388,0.29,0.122)      RGB{N0f8}(0.376,0.314,0.192)
#  RGB{N0f8}(0.251,0.31,0.188)      RGB{N0f8}(0.243,0.306,0.184)
#  RGB{N0f8}(0.431,0.329,0.153)     RGB{N0f8}(0.314,0.369,0.235)
#  RGB{N0f8}(0.38,0.329,0.114)   …  RGB{N0f8}(0.659,0.788,0.463)
#  RGB{N0f8}(0.239,0.149,0.09)      RGB{N0f8}(0.651,0.675,0.467)
#  RGB{N0f8}(0.212,0.09,0.122)      RGB{N0f8}(0.525,0.596,0.314)
# ...

# %%
Pkg.add("Plots"); using Plots
Pkg.add("Measures"); using Measures
# define the Lorenz attractor
mutable struct Lorenz
    dt; σ; ρ; β; x; y; z
end

function step!(l::Lorenz)
    dx = l.σ*(l.y - l.x)       ; l.x += l.dt * dx
    dy = l.x*(l.ρ - l.z) - l.y ; l.y += l.dt * dy
    dz = l.x*l.y - l.β*l.z     ; l.z += l.dt * dz
end

attractor = Lorenz((dt = 0.02, σ = 10., ρ = 30., β = 8//3, x = 1., y = 1., z = 1.)...)


# initialize a 3D plot with 1 empty series
plt = plot3d(1, xlim=(-25,25), ylim=(-25,25), zlim=(0,50),
                title = "Lorenz Attractor", marker = 2)

# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
# ┌ Info: Saved animation to
# │   fn = /Users/rmz/git/julia-playground/tmp.gif
# └ @ Plots /Users/rmz/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/Users/rmz/git/julia-playground/tmp.gif")

# %%
function plot_matrix(my_matrix)
    n,m = collect(size(my_matrix)) .+ 1 .- 1e-10
    f(x,y) = my_matrix[Int(floor(x)), Int(floor(y))]
    Plots.Image(f, (1, m), (1, n))
 end
# Out:
# plot_matrix (generic function with 1 method)

# %%
test = rand(3,3);
plot_matrix(test)
# Out:
# UndefVarError: Image not defined
#
# Stacktrace:
#  [1] plot_matrix(::Array{Float64,2}) at ./In[7]:4
#  [2] top-level scope at In[8]:2

# %%
img=convert(Image, round(UInt8, test))
# Out:
# MethodError: no method matching round(::Type{UInt8}, ::Array{Float64,2})
# Closest candidates are:
#   round(::Type{T}, !Matched::Integer) where T<:Integer at int.jl:545
#   round(::Type{T}, !Matched::Float16) where T<:Integer at float.jl:368
#   round(::Type{T}, !Matched::BigFloat) where T<:Union{Signed, Unsigned} at mpfr.jl:313
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[9]:1

# %%
test
# Out:
# 3×3 Array{Float64,2}:
#  0.344991  0.0496783  0.849304
#  0.286734  0.920956   0.165793
#  0.378406  0.184227   0.867779

# %%
test * 3
# Out:
# 3×3 Array{Float64,2}:
#  1.03497   0.149035  2.54791
#  0.860201  2.76287   0.497379
#  1.13522   0.552682  2.60334

# %%
# Out:
# MethodError: no method matching round(::Type{Int64}, ::Array{Float64,2})
# Closest candidates are:
#   round(::Type{T}, !Matched::Integer) where T<:Integer at int.jl:545
#   round(::Type{T}, !Matched::Float16) where T<:Integer at float.jl:368
#   round(::Type{T}, !Matched::BigFloat) where T<:Union{Signed, Unsigned} at mpfr.jl:313
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[13]:1

# %%
img_gray = rand(Gray, 2, 2)
# Out:
# 2×2 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.209631)  Gray{Float64}(0.0337955)
#  Gray{Float64}(0.906644)  Gray{Float64}(0.153663)

# %%
plt = plot(1)

@gif for i=1:500
        frame = rand(Gray, 2, 2)
        push!(plt, frame)
    end every 10
# Out:
# MethodError: no method matching push!(::Plots.Plot{Plots.GRBackend}, ::Array{Gray{Float64},2})
# Closest candidates are:
#   push!(::Any, ::Any, !Matched::Any) at abstractarray.jl:2159
#   push!(::Any, ::Any, !Matched::Any, !Matched::Any...) at abstractarray.jl:2160
#   push!(!Matched::Array{Any,1}, ::Any) at array.jl:875
#   ...
#
# Stacktrace:
#  [1] macro expansion at ./In[16]:6 [inlined]
#  [2] macro expansion at /Users/rmz/.julia/packages/Plots/qZHsp/src/animation.jl:177 [inlined]
#  [3] top-level scope at ./In[16]:3

# %%
 Pkg.add("FileIO"); Pkg.add("ImageMagick"); Pkg.add("Colors") ; Pkg.add("FixedPointNumbers");  using FileIO, ImageMagick, Colors, FixedPointNumbers
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#  Installed ImageMagick_jll ─ v6.9.10-12+0
#  Installed JpegTurbo_jll ─── v2.0.1+0
#  Installed Zstd_jll ──────── v1.4.4+0
#  Installed Libtiff_jll ───── v4.0.10+0
#  Installed libpng_jll ────── v1.6.37+2
#  Installed Zlib_jll ──────── v1.2.11+8
#  Installed ImageMagick ───── v1.1.2
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [6218d12a] + ImageMagick v1.1.2
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [6218d12a] + ImageMagick v1.1.2
#   [c73af94c] + ImageMagick_jll v6.9.10-12+0
#   [aacddb02] + JpegTurbo_jll v2.0.1+0
#   [89763e89] + Libtiff_jll v4.0.10+0
#   [83775a58] + Zlib_jll v1.2.11+8
#   [3161d3a3] + Zstd_jll v1.4.4+0
#   [b53b4c65] + libpng_jll v1.6.37+2
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
# ...

# %%
save("/tmp/test.gif", rand(RGB{N0f8}, 32, 32, 5))

# %%
 rand(RGB{N0f8}, 32, 32, 5)
# Out:
# 32×32×5 Array{RGB{N0f8},3} with eltype RGB{Normed{UInt8,8}}:
# [:, :, 1] =
#  RGB{N0f8}(0.671,0.682,1.0)    …  RGB{N0f8}(0.678,0.796,0.518)
#  RGB{N0f8}(0.8,0.914,0.529)       RGB{N0f8}(0.498,0.114,0.616)
#  RGB{N0f8}(0.718,0.243,0.227)     RGB{N0f8}(0.58,0.149,0.71)
#  RGB{N0f8}(0.788,0.663,0.122)     RGB{N0f8}(0.38,0.788,0.725)
#  RGB{N0f8}(0.251,0.302,0.067)     RGB{N0f8}(0.612,0.478,0.608)
#  RGB{N0f8}(0.149,0.467,0.49)   …  RGB{N0f8}(0.749,0.62,0.941)
#  RGB{N0f8}(0.667,0.925,0.427)     RGB{N0f8}(0.773,0.357,0.976)
#  RGB{N0f8}(0.965,0.902,0.506)     RGB{N0f8}(0.608,0.58,0.612)
#  RGB{N0f8}(0.196,0.373,0.255)     RGB{N0f8}(0.004,0.678,0.761)
#  RGB{N0f8}(0.263,0.808,0.169)     RGB{N0f8}(0.388,0.031,0.898)
#  RGB{N0f8}(0.859,0.318,0.98)   …  RGB{N0f8}(0.706,0.514,0.898)
#  RGB{N0f8}(0.282,0.294,0.278)     RGB{N0f8}(0.941,0.4,0.749)
#  RGB{N0f8}(0.886,0.945,0.902)     RGB{N0f8}(0.784,0.369,0.486)
#  ⋮                             ⋱
# ...

# %%
## Plan:
#   1. Work on a 10x10 array.
#   2. Two-particle first without, then with animation/collision.
#   3.

# %%
Array{Gray,Float64}(1.0, 10, 10)
# Out:
# MethodError: no method matching Array{Float64,2}(::Float64, ::Int64, ::Int64)
# Closest candidates are:
#   Array{Float64,2}(!Matched::UndefInitializer, ::Int64, ::Int64) where T at boot.jl:406
#   Array{Float64,2}(!Matched::UndefInitializer, ::Int64...) where {T, N} at boot.jl:410
#   Array{Float64,2}(!Matched::UndefInitializer, ::Integer, ::Integer) where T at baseext.jl:13
#   ...
#
# Stacktrace:
#  [1] top-level scope at In[42]:1

# %%
struct Point{T}
           x::T
           y::T
end

# %%
# Out:
# invalid redefinition of constant ParticleState
#
# Stacktrace:
#  [1] top-level scope at /Users/rmz/.julia/packages/IJulia/F1GUo/src/kernel.jl:52

# %%
ParticleState(Point(2.,.2), Point(3.,4.))
# Out:
# MethodError: no method matching ParticleState(::Point{Float64}, ::Point{Float64})
#
# Stacktrace:
#  [1] top-level scope at In[57]:1

# %%
using ParticleMovement
# Out:
# ArgumentError: Package ParticleMovement not found in current path:
# - Run `import Pkg; Pkg.add("ParticleMovement")` to install the ParticleMovement package.
#
#
# Stacktrace:
#  [1] require(::Module, ::Symbol) at ./loading.jl:887
#  [2] top-level scope at In[59]:1

# %%
Point{Float64}(2,2)
# Out:
# Point{Float64}(2.0, 2.0)
