# %%
using TestImages
img = testimage("mandrill")
# Out:
# ┌ Info: Could not find mandrill in directory images/ . Checking if it exists in the online repository.
# └ @ TestImages /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/TestImages/n0RgR/src/TestImages.jl:76
# ┌ Info: Found mandrill in the online repository. Downloading to the images directory.
# └ @ TestImages /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/TestImages/n0RgR/src/TestImages.jl:79
# WARNING: ColorTypes.RGB4 is deprecated, use RGBX instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# WARNING: importing deprecated binding ColorTypes.RGB1 into QuartzImageIO.
# WARNING: ColorTypes.RGB1 is deprecated, use XRGB instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# WARNING: ColorTypes.RGB4 is deprecated, use RGBX instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# WARNING: ColorTypes.RGB1 is deprecated, use XRGB instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# WARNING: ColorTypes.RGB4 is deprecated, use RGBX instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# in read_and_release_imgsrc at /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/QuartzImageIO/AjiIs/src/QuartzImageIO.jl
# WARNING: ColorTypes.RGB1 is deprecated, use XRGB instead.
#   likely near /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/IJulia/F1GUo/src/kernel.jl:52
# in read_and_release_imgsrc at /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/QuartzImageIO/AjiIs/src/QuartzImageIO.jl
# 512×512 Array{RGB{N0f8},2} with eltype ColorTypes.RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.643,0.588,0.278)  …  RGB{N0f8}(0.702,0.737,0.463)
#  RGB{N0f8}(0.471,0.49,0.243)      RGB{N0f8}(0.471,0.541,0.29)
#  RGB{N0f8}(0.388,0.29,0.122)      RGB{N0f8}(0.376,0.314,0.192)
#  RGB{N0f8}(0.251,0.31,0.188)      RGB{N0f8}(0.243,0.306,0.184)
#  RGB{N0f8}(0.431,0.329,0.153)     RGB{N0f8}(0.314,0.369,0.235)
#  RGB{N0f8}(0.38,0.329,0.114)   …  RGB{N0f8}(0.659,0.788,0.463)
#  RGB{N0f8}(0.239,0.149,0.09)      RGB{N0f8}(0.651,0.675,0.467)
#  RGB{N0f8}(0.212,0.09,0.122)      RGB{N0f8}(0.525,0.596,0.314)
#  RGB{N0f8}(0.251,0.212,0.216)     RGB{N0f8}(0.467,0.518,0.29)
#  RGB{N0f8}(0.216,0.125,0.09)      RGB{N0f8}(0.596,0.561,0.239)
#  RGB{N0f8}(0.212,0.106,0.047)  …  RGB{N0f8}(0.369,0.235,0.165)
#  RGB{N0f8}(0.2,0.11,0.059)        RGB{N0f8}(0.243,0.341,0.173)
#  RGB{N0f8}(0.196,0.125,0.063)     RGB{N0f8}(0.408,0.431,0.243)
#  ⋮                             ⋱
#  RGB{N0f8}(0.561,0.659,0.71)   …  RGB{N0f8}(0.322,0.341,0.294)
#  RGB{N0f8}(0.518,0.635,0.608)     RGB{N0f8}(0.373,0.302,0.267)
#  RGB{N0f8}(0.502,0.62,0.541)      RGB{N0f8}(0.325,0.275,0.29)
#  RGB{N0f8}(0.416,0.486,0.498)     RGB{N0f8}(0.267,0.365,0.345)
#  RGB{N0f8}(0.459,0.51,0.463)      RGB{N0f8}(0.278,0.231,0.212)
#  RGB{N0f8}(0.42,0.451,0.467)   …  RGB{N0f8}(0.329,0.337,0.365)
#  RGB{N0f8}(0.38,0.42,0.447)       RGB{N0f8}(0.29,0.353,0.286)
#  RGB{N0f8}(0.365,0.388,0.353)     RGB{N0f8}(0.349,0.325,0.333)
#  RGB{N0f8}(0.376,0.451,0.525)     RGB{N0f8}(0.325,0.357,0.376)
#  RGB{N0f8}(0.475,0.58,0.608)      RGB{N0f8}(0.318,0.314,0.235)
#  RGB{N0f8}(0.494,0.663,0.659)  …  RGB{N0f8}(0.314,0.247,0.278)
#  RGB{N0f8}(0.035,0.043,0.047)     RGB{N0f8}(0.016,0.02,0.008)
# ┌ Warning: Output swatches are reduced due to the large size (512×512).
# │ Load the ImageShow package for large images.
# └ @ Colors /Users/rmz/.juliapro/JuliaPro_v1.2.0-1/packages/Colors/P2rUx/src/display.jl:148

# %%
 img = @view rand(4, 4)
# Out:
# ArgumentError: Invalid use of @view macro: argument must be a reference expression A[...].
#
# Stacktrace:
#  [1] @view(::LineNumberNode, ::Module, ::Any) at ./views.jl:114

# %%
img_gray = rand(Gray, 2, 2)
# Out:
# UndefVarError: Gray not defined
#
# Stacktrace:
#  [1] top-level scope at In[8]:1

# %%
Pkg.add("Unitful");Pkg.add("AxisArrays")
using Unitful, AxisArrays
using Unitful: mm, s
# Out:
#  Resolving package versions...
#   Updating `~/.juliapro/JuliaPro_v1.2.0-1/environments/v1.2/Project.toml`
#  [no changes]
#   Updating `~/.juliapro/JuliaPro_v1.2.0-1/environments/v1.2/Manifest.toml`
#  [no changes]
#  Resolving package versions...
#   Updating `~/.juliapro/JuliaPro_v1.2.0-1/environments/v1.2/Project.toml`
#   [39de3d68] + AxisArrays v0.3.3
#   Updating `~/.juliapro/JuliaPro_v1.2.0-1/environments/v1.2/Manifest.toml`
#  [no changes]

# %%
Pkg.add("Plots"); using Plots
Pkg.add("Measures"); using Measures
# define the Lorenz attractor
mutable struct Lorenz
    dt; σ; ρ; β; x; y; z
end

function step!(l::Lorenz)
    dx = l.σ*(l.y - l.x)       ; l.x += l.dt * dx
    dy = l.x*(l.ρ - l.z) - l.y ; l.y += l.dt * dy
    dz = l.x*l.y - l.β*l.z     ; l.z += l.dt * dz
end

attractor = Lorenz((dt = 0.02, σ = 10., ρ = 28., β = 8//3, x = 1., y = 1., z = 1.)...)


# initialize a 3D plot with 1 empty series
plt = plot3d(1, xlim=(-25,25), ylim=(-25,25), zlim=(0,50),
                title = "Lorenz Attractor", marker = 2)

# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
#  Resolving package versions...
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Please Authenticate..
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:47
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:108
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# Error when installing package RecipesBase:
# MethodError: no method matching download(::String, ::String, ::Nothing)
# Closest candidates are:
#   download(::AbstractString, ::AbstractString) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/CredentialsHandler/src/CredentialsHandler.jl:89
#   download(::AbstractString, ::AbstractString, !Matched::CredentialsHandler.Token) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/CredentialsHandler/src/CredentialsHandler.jl:89
# Stacktrace:
#  [1] download(::String, ::String) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/CredentialsHandler/src/CredentialsHandler.jl:89
#  [2] (::getfield(BinaryProvider.JuliaTeam, Symbol("##1#2")){getfield(BinaryProvider, Symbol("##49#72")){getfield(BinaryProvider, Symbol("##31#54")){String}}})(::String, ::String) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/BinaryProvider/src/JuliaTeam.jl:18
#  [3] #download#93(::Bool, ::typeof(BinaryProvider.download), ::String, ::String) at /Applications/JuliaPro-1.2.0-1.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [4] download at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/BinaryProvider/src/PlatformEngines.jl:493 [inlined]
#  [5] install_archive(::Array{String,1}, ::Base.SHA1, ::Base.UUID, ::String) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Operations.jl:517
#  [6] macro expansion at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Operations.jl:659 [inlined]
#  [7] (::getfield(Pkg.Operations, Symbol("##26#29")){Symbol,Pkg.Types.Context,Dict{Base.UUID,Base.SHA1},Dict{Base.UUID,Array{String,1}},Channel{Any},Channel{Any}})() at ./task.jl:268
#
# Stacktrace:
#  [1] pkgerror(::String, ::Vararg{String,N} where N) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Types.jl:121
#  [2] #apply_versions#23(::Symbol, ::typeof(Pkg.Operations.apply_versions), ::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}, ::Dict{Base.UUID,Base.SHA1}, ::Dict{Base.UUID,Array{String,1}}) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Operations.jl:677
#  [3] #apply_versions at ./none:0 [inlined]
#  [4] #apply_versions#22 at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Operations.jl:614 [inlined]
#  [5] #apply_versions at ./none:0 [inlined]
#  [6] #add_or_develop#63(::Array{Base.UUID,1}, ::Symbol, ::typeof(Pkg.Operations.add_or_develop), ::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/Operations.jl:1236
#  [7] #add_or_develop at ./none:0 [inlined]
#  [8] #add_or_develop#17(::Symbol, ::Bool, ::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(Pkg.API.add_or_develop), ::Pkg.Types.Context, ::Array{Pkg.Types.PackageSpec,1}) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:59
#  [9] #add_or_develop at ./none:0 [inlined]
#  [10] #add_or_develop#16 at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:36 [inlined]
#  [11] #add_or_develop at ./none:0 [inlined]
#  [12] #add_or_develop#13 at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:34 [inlined]
#  [13] #add_or_develop at ./none:0 [inlined]
#  [14] #add_or_develop#12(::Base.Iterators.Pairs{Symbol,Symbol,Tuple{Symbol},NamedTuple{(:mode,),Tuple{Symbol}}}, ::typeof(Pkg.API.add_or_develop), ::String) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:33
#  [15] #add_or_develop at ./none:0 [inlined]
#  [16] #add#22 at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:64 [inlined]
#  [17] add(::String) at /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/Pkg/src/API.jl:64
#  [18] top-level scope at In[11]:1
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Info: Auth Timeout : token not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:64
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91
# ┌ Error: token.toml not found in /Users/rmz/.juliapro/token.toml. Please get it from https://pkg.juliacomputing.com/
# └ @ TokenManager /Users/vagrant/worker/juliapro-release-osx1011-0_6/build/tmp_julia/Julia-1.2.app/Contents/Resources/julia/share/julia/stdlib/v1.2/TokenManager/src/TokenManager.jl:91

# %%
anim = @animate for i=1:100
    plot(...)
end
gif(anim, "/tmp/anim_fps15.gif", fps = 15)
